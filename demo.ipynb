# %%
from hagstofan.hagstofan import Hagstofan

# %%
hagstofan = Hagstofan()

# %%
hagstofan.databases
# Out:
# dict_keys(['Atvinnuvegir', 'Efnahagur', 'Ibuar', 'Samfelag', 'Sogulegar', 'Umhverfi'])

# %%
hagstofan.search_datasets('').head()
# Out:
#            dbid           id  \
# 0  Atvinnuvegir  SAM02001.px
# 1  Atvinnuvegir  SAM02002.px
# 2  Atvinnuvegir  SAM02003.px
# 3  Atvinnuvegir  SAM02000.px
# 4  Atvinnuvegir  SAM02004.px
#
#                                                 text  \
# 0  Farþegar um Keflavíkurflugvöll eftir rikisfang...
# 1  Farþegar með skemmtiferðaskipum til Reykjavíku...
# 2  Farþegar og ökutæki með bílferjum til landsins...
# 3  Farþegar og ferðamenn í gegnum Keflavíkurflugv...
# 4   Farþegar til landsins eftir ríkisfangi 1997-2000
#
#                                                  url
# 0  https://px.hagstofa.is/pxis/api/v1/is/Atvinnuv...
# 1  https://px.hagstofa.is/pxis/api/v1/is/Atvinnuv...
# 2  https://px.hagstofa.is/pxis/api/v1/is/Atvinnuv...
# 3  https://px.hagstofa.is/pxis/api/v1/is/Atvinnuv...
# 4  https://px.hagstofa.is/pxis/api/v1/is/Atvinnuv...

# %%
hagstofan.get_data(database='Efnahagur', table='VIS01000.px').head()
# Out:
#   Mánuður_id Mánuður_label Vísitala_id        Vísitala_label   Liður_id  \
# 0    1988M05       1988M05         CPI  Vísitala neysluverðs      index
# 1    1988M05       1988M05         CPI  Vísitala neysluverðs   change_M
# 2    1988M05       1988M05         CPI  Vísitala neysluverðs   change_A
# 3    1988M05       1988M05         CPI  Vísitala neysluverðs   A_rate_M
# 4    1988M05       1988M05         CPI  Vísitala neysluverðs  A_rate_3M
#
#                        Liður_label  Value
# 0                         Vísitala  100.0
# 1               Mánaðarbreyting, %    NaN
# 2                   Ársbreyting, %    NaN
# 3     Ársbreyting síðasta mánuð, %    NaN
# 4  Ársbreyting síðustu 3 mánuði, %    NaN

# %%
hagstofan.get_updates(database='Efnahagur', cutoff_date='2023-08').sort_values('updated', ascending=False)
# Out:
#          dbid           id                                               text  \
# 15  Efnahagur  THJ08405.px                 Afskriftir atvinnugreina 1997-2022
# 14  Efnahagur  THJ08404.px               Vinnsluvirði atvinnugreina 1997-2022
# 24  Efnahagur  THJ01301.px  Árlegur meðalvöxtur þjóðartekna og mannfjölda ...
# 23  Efnahagur  THJ01202.px  Þjóðhagslegur sparnaður og lánahreyfingar 1980...
# 22  Efnahagur  THJ01104.px  Vísitölur landsframleiðslu og einstakra þátta ...
# ..        ...          ...                                                ...
# 69  Efnahagur  VIS02002.px  Samræmd vísitala neysluverðs eftir löndum og m...
# 70  Efnahagur  VIS02100.px  Sundurliðun breytinga meginflokka, júlí 2022-2023
# 71  Efnahagur  VIS02202.px  Undirvísitölur samræmdrar vísitölu neysluverðs...
# 1   Efnahagur  THJ00111.px                        Framleiðsla, sala og umsvif
# 2   Efnahagur  THJ00113.px                                       Ferðaiðnaður
#
#                updated
# 15 2023-09-06 10:14:57
# 14 2023-09-06 10:14:57
# 24 2023-09-06 10:14:57
# 23 2023-09-06 10:14:57
# 22 2023-09-06 10:14:57
# ..                 ...
# 69 2023-08-22 08:58:17
# 70 2023-08-22 08:58:17
# 71 2023-08-22 08:58:17
# 1  2023-08-09 08:58:22
# 2  2023-08-09 08:58:22
#
# [75 rows x 4 columns]
